# %%
import sys
import os
sys.path.append(os.getcwd())
from collections import defaultdict
import h5py as h5
import numpy as np
import utils

# %%
template_files = [f for f in os.listdir("./templates")]

# %%
for template_file in template_files:
    tmp_data = utils.load_template(template_file,'./templates/')
    print(tmp_data)
# Out:
# {'depth': array([5.688252]), 'latitude': array([44.500587]), 'longitude': array([6.6641645]), 'moveouts_P': array([0], dtype=int32), 'moveouts_S': array([0], dtype=int32), 'origin_time': 1694277684.0, 'p_travel_times': array([0]), 's_travel_times': array([0]), 'sampling_rate': array([250.]), 'stations': array([b'3010356'], dtype='|S7'), 'waveforms': array([[[-3.29337997e+01, -4.84839592e+01, -1.40396404e+01,
#           8.24714959e-01, -1.73402576e+01,  7.69949722e+00,
#          -2.54775295e+01, -3.60382881e+01, -1.86311760e+01,
#          -2.43450146e+01,  1.21894541e+01, -6.72555494e+00,
#          -2.19997234e+01, -3.12525845e+01, -4.40510483e+01,
#          -2.06032777e+00,  6.57631159e+00, -8.22021544e-01,
#          -3.38351402e+01, -3.95605125e+01, -9.32480335e-01,
#          -1.81344357e+01, -2.11693192e+01, -1.32156324e+01,
#          -1.49029703e+01, -4.74115992e+00, -3.26145020e+01,
#          -4.27661972e+01, -8.54583549e+00,  2.47543001e+00,
# ...
